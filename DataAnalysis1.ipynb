# %%
import pandas as pd

# %%
df_store = pd.read_csv("/content/stores_data_set.csv")
df_sales = pd.read_csv("/content/sales_data_set.csv")
df_features = pd.read_csv("/content/Features_data_set.csv")

# %%
df_store.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
df_sales.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
df_features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df_features.drop(columns="IsHoliday",axis=1,inplace=True) # axis = 0 is row, axis =1 is column

# %%
df_features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment
# 0        NaN        NaN        NaN  211.096358         8.106
# 1        NaN        NaN        NaN  211.242170         8.106
# 2        NaN        NaN        NaN  211.289143         8.106
# 3        NaN        NaN        NaN  211.319643         8.106
# 4        NaN        NaN        NaN  211.350143         8.106

# %%
df_store_sales= pd.merge(df_store,df_sales,on="Store")

# %%
df_store_sales.shape
# Out:
# (421570, 7)

# %%
df_store_sales.head(10)
# Out:
#    Store Type    Size  Dept        Date  Weekly_Sales  IsHoliday
# 0      1    A  151315     1  05/02/2010      24924.50      False
# 1      1    A  151315     1  12/02/2010      46039.49       True
# 2      1    A  151315     1  19/02/2010      41595.55      False
# 3      1    A  151315     1  26/02/2010      19403.54      False
# 4      1    A  151315     1  05/03/2010      21827.90      False
# 5      1    A  151315     1  12/03/2010      21043.39      False
# 6      1    A  151315     1  19/03/2010      22136.64      False
# 7      1    A  151315     1  26/03/2010      26229.21      False
# 8      1    A  151315     1  02/04/2010      57258.43      False
# 9      1    A  151315     1  09/04/2010      42960.91      False

# %%
df_final = pd.merge(df_features,df_store_sales,on=["Store","Date"])

# %%
df_final.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  05/02/2010        42.31       2.572        NaN        NaN
# 2      1  05/02/2010        42.31       2.572        NaN        NaN
# 3      1  05/02/2010        42.31       2.572        NaN        NaN
# 4      1  05/02/2010        42.31       2.572        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment Type    Size  \
# 0        NaN        NaN        NaN  211.096358         8.106    A  151315
# 1        NaN        NaN        NaN  211.096358         8.106    A  151315
# 2        NaN        NaN        NaN  211.096358         8.106    A  151315
# 3        NaN        NaN        NaN  211.096358         8.106    A  151315
# 4        NaN        NaN        NaN  211.096358         8.106    A  151315
#
#    Dept  Weekly_Sales  IsHoliday
# 0     1      24924.50      False
# 1     2      50605.27      False
# 2     3      13740.12      False
# 3     4      39954.04      False
# 4     5      32229.38      False

# %%
df_final.shape
# Out:
# (421570, 16)

# %%
df_store_sales.shape
# Out:
# (421570, 7)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Date          421570 non-null  object
#  2   Temperature   421570 non-null  float64
#  3   Fuel_Price    421570 non-null  float64
#  4   MarkDown1     150681 non-null  float64
#  5   MarkDown2     111248 non-null  float64
#  6   MarkDown3     137091 non-null  float64
#  7   MarkDown4     134967 non-null  float64
#  8   MarkDown5     151432 non-null  float64
#  9   CPI           421570 non-null  float64
#  10  Unemployment  421570 non-null  float64
#  11  Type          421570 non-null  object
#  12  Size          421570 non-null  int64
#  13  Dept          421570 non-null  int64
#  14  Weekly_Sales  421570 non-null  float64
#  15  IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(10), int64(3), object(2)
# memory usage: 48.6+ MB

# %%
df_final["Date"]=pd.to_datetime(df_final["Date"],format="%d/%m/%Y")

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Date          421570 non-null  datetime64[ns]
#  2   Temperature   421570 non-null  float64
#  3   Fuel_Price    421570 non-null  float64
#  4   MarkDown1     150681 non-null  float64
#  5   MarkDown2     111248 non-null  float64
#  6   MarkDown3     137091 non-null  float64
#  7   MarkDown4     134967 non-null  float64
#  8   MarkDown5     151432 non-null  float64
#  9   CPI           421570 non-null  float64
#  10  Unemployment  421570 non-null  float64
#  11  Type          421570 non-null  object
#  12  Size          421570 non-null  int64
#  13  Dept          421570 non-null  int64
#  14  Weekly_Sales  421570 non-null  float64
#  15  IsHoliday     421570 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 48.6+ MB

# %%
df_final["Year"] = df_final["Date"].dt.year

# %%
df_final.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 2      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 3      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 4      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment Type    Size  Dept  \
# 0        NaN        NaN  211.096358         8.106    A  151315     1
# 1        NaN        NaN  211.096358         8.106    A  151315     2
# 2        NaN        NaN  211.096358         8.106    A  151315     3
# 3        NaN        NaN  211.096358         8.106    A  151315     4
# 4        NaN        NaN  211.096358         8.106    A  151315     5
#
#    Weekly_Sales  IsHoliday  Year
# 0      24924.50      False  2010
# 1      50605.27      False  2010
# 2      13740.12      False  2010
# 3      39954.04      False  2010
# 4      32229.38      False  2010

# %%
df_final["Month"] = df_final["Date"].dt.month
df_final["Day"] = df_final["Date"].dt.day
df_final["Day_of_week"] = df_final["Date"].dt.day_of_week
df_final["Week"] = df_final["Date"].dt.isocalendar().week

# %%
df_final.tail(100)
# Out:
#         Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 421470     45 2012-10-19        56.47       3.969    2004.02        NaN
# 421471     45 2012-10-19        56.47       3.969    2004.02        NaN
# 421472     45 2012-10-19        56.47       3.969    2004.02        NaN
# 421473     45 2012-10-19        56.47       3.969    2004.02        NaN
# 421474     45 2012-10-19        56.47       3.969    2004.02        NaN
# ...       ...        ...          ...         ...        ...        ...
# 421565     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421566     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421567     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421568     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421569     45 2012-10-26        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  ...  Type    Size  Dept  \
# 421470       3.18     437.73    1537.49  192.330854  ...     B  118221    35
# 421471       3.18     437.73    1537.49  192.330854  ...     B  118221    36
# 421472       3.18     437.73    1537.49  192.330854  ...     B  118221    38
# 421473       3.18     437.73    1537.49  192.330854  ...     B  118221    40
# 421474       3.18     437.73    1537.49  192.330854  ...     B  118221    41
# ...           ...        ...        ...         ...  ...   ...     ...   ...
# 421565     100.00     211.94     858.33  192.308899  ...     B  118221    93
# 421566     100.00     211.94     858.33  192.308899  ...     B  118221    94
# 421567     100.00     211.94     858.33  192.308899  ...     B  118221    95
# 421568     100.00     211.94     858.33  192.308899  ...     B  118221    97
# 421569     100.00     211.94     858.33  192.308899  ...     B  118221    98
#
#         Weekly_Sales  IsHoliday  Year  Month  Day  Day_of_week  Week
# 421470       2274.09      False  2012     10   19            4    42
# 421471       1119.59      False  2012     10   19            4    42
# 421472      54427.64      False  2012     10   19            4    42
# 421473      38408.23      False  2012     10   19            4    42
# 421474       2125.11      False  2012     10   19            4    42
# ...              ...        ...   ...    ...  ...          ...   ...
# 421565       2487.80      False  2012     10   26            4    43
# 421566       5203.31      False  2012     10   26            4    43
# 421567      56017.47      False  2012     10   26            4    43
# 421568       6817.48      False  2012     10   26            4    43
# 421569       1076.80      False  2012     10   26            4    43
#
# [100 rows x 21 columns]
